# %%
# Import libraries
import pandas as pd
import numpy as np
import datetime as dt

# %%
# Import the map to nhl player id data
nhl_id_mapping = pd.read_csv(r'../Data/map_player_nhl.csv')

# %%
# Import the trade dates data
trade_dates = pd.read_csv(r'../Data/trade_dates.csv')

# %%
# Import the traded players stats from the season before being traded.
traded_players_pre_season = pd.read_csv(r'../Data/traded_skater_platform.csv')

# %%
# Import the gen info data
gen_info = pd.read_csv(r'../Data/traded_player_general_info.csv')

# %%
nhl_id_mapping.columns
# Out:
# Index(['playerId', 'nhlPlayerId'], dtype='object')

# %%
# Merge trade dates and players data
first_merge = pd.merge(traded_players_pre_season, nhl_id_mapping, on='playerId')

# %%
# Merge last result with trade dates data
second_merge = pd.merge(first_merge, trade_dates, on='tradeId', how='inner')

# %%
# Merge last result with the general player info data
third_merge = pd.merge(second_merge, gen_info, on=['playerId','position'], how='inner')

# %%
third_merge.shape
# Out:
# (1488, 32)

# %%
third_merge.columns
# Out:
# Index(['playerId', 'position', 'positionGeneral_x', 'league', 'leagueLevel',
#        'tradeId', 'regularGamesPlayed', 'regularGoals', 'regularAssists',
#        'regularPenaltyMinutes', 'postseasonGamesPlayed', 'postseasonGoals',
#        'postseasonAssists', 'postseasonPenaltyMinutes', 'regular_hits',
#        'regular_blockedShots', 'regular_powerplayGoals', 'regular_shots',
#        'regular_atoi', 'regular_pp_atoi', 'regular_pk_atoi', 'nhlPlayerId',
#        'trade_date', 'positionGeneral_y', 'height_cm', 'weight_kg',
#        'handedness', 'dateOfBirth', 'birthCountry', 'draftYear', 'draftRound',
#        'draftOverallPick'],
#       dtype='object')

# %%
# Pull the year out of the trade date
third_merge['trade_year'] = pd.to_datetime(third_merge['trade_date']).dt.year

# %%
third_merge['trade_year'].value_counts()
# Out:
# trade_year
# 2023    144
# 2024    118
# 2011    102
# 2025     99
# 2013     95
# 2017     93
# 2018     93
# 2019     92
# 2022     92
# 2010     92
# 2021     91
# 2016     85
# 2020     80
# 2015     78
# 2014     66
# 2012     56
# 2009     12
# Name: count, dtype: int64

# %%
# Make a separate column with just the season month and day combination
third_merge['trade_month_day'] = pd.to_datetime(third_merge['trade_date']).dt.strftime('%m-%d')

# %%
# Create a boolean variable for if the player was traded in the off-season
third_merge['off-season_trade'] = np.where(third_merge['trade_month_day'].between('04-01', '10-06'), 1, 0)

# %%
third_merge['off-season_trade'].value_counts()
# Out:
# off-season_trade
# 0    1038
# 1     450
# Name: count, dtype: int64

# %%
# Transform months; For example 22-23 -> 2022
team_data['Season'] = team_data['Season'].apply(lambda x: '2024' if x == '24-25' else ('2023' if x == '23-24' else ('2022' if x == '22-23' else ('2021' if x == '21-22' else ('2020' if x == '20-21' else ('2019' if x == '19-20' else ('2018' if x == '18-19' else ('2017' if x == '17-18' else ('2016' if x == '16-17' else ('2015' if x == '15-16' else ('2014' if x == '14-15' else ('2013' if x == '13-14' else ('2012' if x == '12-13' else ('2011' if x == '11-12' else ('2010' if x == '10-11' else ('2009' if x == '09-10' else ('2008' if x == '08-09' else (None))))))))))))))))))

# %%
third_merge[third_merge['trade_year'] == 2025]
# Out:
#       playerId position positionGeneral_x league   leagueLevel  tradeId  \
# 23       48836        C                 F    nhl  professional     1335
# 46       84550        D                 D    nhl  professional     1290
# 52      206642        C                 F    nhl  professional     1230
# 83      787453       RD                 D    nhl  professional     2541
# 98      577126       RW                 F    nhl  professional     1807
# ...        ...      ...               ...    ...           ...      ...
# 1433    797693        F                 F    nhl  professional     2477
# 1462     60761       LW                 F    nhl  professional     4066
# 1464    156795       RW                 F    nhl  professional     5213
# 1465    619032       LD                 D    nhl  professional     1471
# 1480    844145       LW                 F    nhl  professional     2601
#
#       regularGamesPlayed  regularGoals  regularAssists  regularPenaltyMinutes  \
# 23                    70            15               8                     18
# 46                    22             1               5                      4
# 52                    59             7               7                     18
# 83                    48             0               3                     45
# 98                    67            11              12                     28
# ...                  ...           ...             ...                    ...
# 1433                   7             1               0                      0
# 1462                  67            29              45                     42
# 1464                  21             2               3                      2
# 1465                  47             0               8                     12
# 1480                  13             0               0                     18
#
#       ...  weight_kg  handedness  dateOfBirth   birthCountry  draftYear  \
# 23    ...       99.0           R   1992-03-02  United States     2010.0
# 46    ...      100.0           R   2002-05-26  United States     2022.0
# 52    ...       82.0           L   2000-02-03  United States     2018.0
# 83    ...       91.0           R   1996-05-29         Canada     2016.0
# 98    ...       83.0           L   2000-02-25  United States     2018.0
# ...   ...        ...         ...          ...            ...        ...
# 1433  ...       83.0           R   2005-01-21         Canada     2023.0
# 1462  ...       96.0           L   1996-10-29        Finland     2015.0
# 1464  ...       89.0           R   1997-03-17    Netherlands     2015.0
# 1465  ...       89.0           L   1991-05-09         Canada     2009.0
# 1480  ...       97.0           L   1998-02-27         Canada     2016.0
#
#       draftRound  draftOverallPick  trade_year  trade_month_day  \
# 23           1.0              28.0        2025            03-07
# 46           5.0             159.0        2025            01-31
# 52           2.0              42.0        2025            01-24
# 83           7.0             183.0        2025            01-31
# 98           1.0              14.0        2025            01-30
# ...          ...               ...         ...              ...
# 1433         1.0              27.0        2025            03-06
# 1462         1.0              10.0        2025            03-07
# 1464         2.0              46.0        2025            03-07
# 1465         1.0              12.0        2025            03-01
# 1480         2.0              46.0        2025            03-07
#
#       off-season_trade
# 23                   0
# 46                   0
# 52                   0
# 83                   0
# 98                   0
# ...                ...
# 1433                 0
# 1462                 0
# 1464                 0
# 1465                 0
# 1480                 0
#
# [99 rows x 35 columns]
